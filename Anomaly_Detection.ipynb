# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#the dataset is put in the dataframe(df) and it's first 5 rows are printed
df=pd.read_csv("Train_data.csv")
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
#the class column is traversed and the rows having 'anomaly' are printed
df[df['class']=='anomaly'].head(20)
# Out:
#     duration protocol_type     service flag  src_bytes  dst_bytes  land  \
# 2          0           tcp     private   S0          0          0     0
# 5          0           tcp     private  REJ          0          0     0
# 6          0           tcp     private   S0          0          0     0
# 7          0           tcp     private   S0          0          0     0
# 8          0           tcp  remote_job   S0          0          0     0
# 9          0           tcp     private   S0          0          0     0
# 10         0           tcp     private  REJ          0          0     0
# 11         0           tcp     private   S0          0          0     0
# 13         0           tcp    ftp_data   SF        334          0     0
# 14         0           tcp        name   S0          0          0     0
# 15         0           tcp  netbios_ns   S0          0          0     0
# 17         0          icmp       eco_i   SF         18          0     0
# ...

# %%
df.columns
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot',
#        'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell',
#        'su_attempted', 'num_root', 'num_file_creations', 'num_shells',
#        'num_access_files', 'num_outbound_cmds', 'is_host_login',
#        'is_guest_login', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate', 'class'],
#       dtype='object')

# %%
#this summarises the columns and their types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25192 entries, 0 to 25191
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     25192 non-null  int64
#  1   protocol_type                25192 non-null  object
#  2   service                      25192 non-null  object
#  3   flag                         25192 non-null  object
#  4   src_bytes                    25192 non-null  int64
#  5   dst_bytes                    25192 non-null  int64
#  6   land                         25192 non-null  int64
#  7   wrong_fragment               25192 non-null  int64
#  8   urgent                       25192 non-null  int64
#  9   hot                          25192 non-null  int64
#  10  num_failed_logins            25192 non-null  int64
#  11  logged_in                    25192 non-null  int64
#  12  num_compromised              25192 non-null  int64
# ...

# %%
#gives total no. of rows and columns
df.shape
# Out:
# (25192, 42)

# %%
#counts the no. of missing values in each column
df.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
#it gives the various stats for better understanding of data
df.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# ...

# %%
#function of seaborn lib and gives the no.of occurences in the selected column
sns.countplot(data=df,x="class",palette="rocket")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
#again used counterplot function but this time more specific with two categorical variables
sns.countplot(data=df,x="protocol_type",hue="class",palette="rocket")
# Out:
# <AxesSubplot:xlabel='protocol_type', ylabel='count'>

# %%
#adjusted dimension of plot and became more specific and showed anomaly in flags
plt.figure(figsize=(20,10))
sns.countplot(data=df,x="flag",hue="class",palette="rocket")
# Out:
# <AxesSubplot:xlabel='flag', ylabel='count'>

# %%
#correlation matrix of the columns of datatset
plt.figure(figsize=(40,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Encoding character variables as ml learns in numeric terms
from sklearn.preprocessing import LabelEncoder
before=df[['protocol_type','service','flag','class']]
for col in df.columns:
   if df[col].dtype=="object":
    le_col=LabelEncoder()
    df[col]=le_col.fit_transform(df[col])
after=df[['protocol_type','service','flag','class']]

# %%
df.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              1       19     9        491          0     0
# 1         0              2       41     9        146          0     0
# 2         0              1       46     5          0          0     0
# 3         0              1       22     9        232       8153     0
# 4         0              1       22     9        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# ...

# %%
before.head()
# Out:
#   protocol_type   service flag    class
# 0           tcp  ftp_data   SF   normal
# 1           udp     other   SF   normal
# 2           tcp   private   S0  anomaly
# 3           tcp      http   SF   normal
# 4           tcp      http   SF   normal

# %%
after.head()
# Out:
#    protocol_type  service  flag  class
# 0              1       19     9      1
# 1              2       41     9      1
# 2              1       46     5      0
# 3              1       22     9      1
# 4              1       22     9      1

# %%
#displays icmp after encoding
after[before['protocol_type']=='icmp'].head()
# Out:
#     protocol_type  service  flag  class
# 17              0       13     9      0
# 30              0       13     9      0
# 56              0       13     9      0
# 72              0       61     9      1
# 83              0       13     9      0

# %%
#displays the flag at loc 17
after.loc[17]['flag']
# Out:
# 9

# %%
#built a dictionary of labels before and after encoding so that it is easier to identify
p=before.protocol_type.unique()
p1=[ df.loc[df['protocol_type']==i].index[0] for i in df['protocol_type'].unique()]
d1={}
for i in range(len(p)):
    d1[p[i]]=after.loc[p1[i]]['protocol_type']
print(d1)

q=before.service.unique()
p2=[df.loc[df['service']==i].index[0] for i in df['service'].unique()]
d2={}
for i in range(len(q)):
    d2[q[i]]=after.loc[p2[i]]['service']
print(d2)


r=before.flag.unique()
p3=[df.loc[df['flag']==i].index[0] for i in df['flag'].unique()]
d3={}
for i in range(len(r)):
    d3[r[i]]=after.loc[p3[i]]['flag']
print(d3)


s=before['class'].unique()
p4=[df.loc[df['class']==i].index[0] for i in df['class'].unique()]
d4={}
for i in range(len(s)):
    d4[s[i]]=after.loc[p4[i]]['class']
print(d4)
# Out:
# {'tcp': 1, 'udp': 2, 'icmp': 0}
# {'ftp_data': 19, 'other': 41, 'private': 46, 'http': 22, 'remote_job': 48, 'name': 33, 'netbios_ns': 35, 'eco_i': 13, 'mtp': 32, 'telnet': 57, 'finger': 17, 'domain_u': 11, 'supdup': 55, 'uucp_path': 63, 'Z39_50': 2, 'smtp': 51, 'csnet_ns': 6, 'uucp': 62, 'netbios_dgm': 34, 'urp_i': 61, 'auth': 3, 'domain': 10, 'ftp': 18, 'bgp': 4, 'ldap': 29, 'ecr_i': 14, 'gopher': 20, 'vmnet': 64, 'systat': 56, 'http_443': 23, 'efs': 15, 'whois': 65, 'imap4': 25, 'iso_tsap': 26, 'echo': 12, 'klogin': 27, 'link': 30, 'sunrpc': 54, 'login': 31, 'kshell': 28, 'sql_net': 52, 'time': 59, 'hostnames': 21, 'exec': 16, 'ntp_u': 40, 'discard': 9, 'nntp': 39, 'courier': 5, 'ctf': 7, 'ssh': 53, 'daytime': 8, 'shell': 50, 'netstat': 37, 'pop_3': 44, 'nnsp': 38, 'IRC': 0, 'pop_2': 43, 'printer': 45, 'tim_i': 58, 'pm_dump': 42, 'red_i': 47, 'netbios_ssn': 36, 'rje': 49, 'X11': 1, 'urh_i': 60, 'http_8001': 24}
# ...

# %%
#feature selection using mutual info(how much info can be extracted from one r.v given another)
from sklearn.feature_selection import mutual_info_classif
X = df.drop(['class'],axis=1)
y=df['class']
mutual_info=mutual_info_classif(X,y)
mutual_info
# Out:
# array([2.93180296e-02, 4.02261957e-02, 4.66327562e-01, 3.60762839e-01,
#        5.63398496e-01, 4.37354748e-01, 0.00000000e+00, 2.28942046e-03,
#        0.00000000e+00, 9.37516780e-03, 0.00000000e+00, 2.77947611e-01,
#        4.20808347e-03, 0.00000000e+00, 4.66948128e-04, 8.68736889e-03,
#        0.00000000e+00, 2.22700999e-03, 2.68622243e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.63605497e-01, 6.51256481e-02,
#        2.72224418e-01, 2.64765916e-01, 3.41421700e-02, 3.71010355e-02,
#        3.53577033e-01, 3.57413692e-01, 9.66247698e-02, 1.32826614e-01,
#        3.30843421e-01, 3.04508015e-01, 2.90915114e-01, 1.32225698e-01,
#        1.80526748e-01, 2.85079367e-01, 2.75585750e-01, 3.77619817e-02,
#        6.12352742e-02])

# %%
#we analyse the mutual info recieved and plot a graph in descending order for noise reduction
mutual_info = pd.Series(mutual_info)
mutual_info.index=X.columns
mutual_info=mutual_info.sort_values(ascending=False)
mutual_info.plot.bar(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#picked best 26 features and reduced data
from sklearn.feature_selection import SelectKBest
best_cols=SelectKBest(mutual_info_classif,k=26)
print(best_cols)
# Out:
# SelectKBest(k=26,
#             score_func=<function mutual_info_classif at 0x000001E6A381F3A0>)

# %%
#print features
best_cols.fit(X,y)
selected_features = X.columns[best_cols.get_support()]
print(selected_features)
# Out:
# Index(['duration', 'protocol_type', 'service', 'flag', 'src_bytes',
#        'dst_bytes', 'logged_in', 'count', 'srv_count', 'serror_rate',
#        'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate',
#        'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count',
#        'dst_host_srv_count', 'dst_host_same_srv_rate',
#        'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate',
#        'dst_host_srv_diff_host_rate', 'dst_host_serror_rate',
#        'dst_host_srv_serror_rate', 'dst_host_rerror_rate',
#        'dst_host_srv_rerror_rate'],
#       dtype='object')

# %%
#modify the dataset according to selected features
X=X[selected_features]

# %%
#splitting of dataset for preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
#scale the data for better comparison of features and improved performance
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
#print
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (17634, 26) (7558, 26)
# (17634,) (7558,)

# %%
#using random forest classifier , we calculated the training time for the model
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

import time

clfr = RandomForestClassifier(n_estimators = 30)
start = time.time()

clfr.fit(X_train, y_train.values.ravel())

end = time.time()
     
print("Training time of RandomForestClassifier: ", end-start)
# Out:
# Training time of RandomForestClassifier:  0.40852832794189453

# %%
#evaluating model performance
print("Train score is:", clfr.score(X_train, y_train))
print("Test score is:", clfr.score(X_test, y_test))
# Out:
# Train score is: 1.0
# Test score is: 0.9978830378406987

# %%
#using naive bayes classfier , we calculated the training time for the model
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

clfg = GaussianNB()
start = time.time()
clfg.fit(X_train, y_train)
end = time.time()
print("Training time of Navie Bayes: ", end-start)
# Out:
# Training time of Navie Bayes:  0.01591038703918457

# %%
#evaluating model performance
print("Train score is:", clfg.score(X_train, y_train))
print("Test score is:", clfg.score(X_test, y_test))
# Out:
# Train score is: 0.8775093569241239
# Test score is: 0.8920349298756285

# %%
#using decision tree , we calculated the training time for the model
from sklearn.tree import DecisionTreeClassifier

clfd = DecisionTreeClassifier(criterion ="entropy", max_depth = 4)
start = time.time()

clfd.fit(X_train, y_train)
end = time.time()
print("Training time of Decision Tree: ", end-start)
# Out:
# Training time of Decision Tree:  0.05625462532043457

# %%
#evaluating model performance
print("Train score is:", clfd.score(X_train, y_train))
print("Test score is:", clfd.score(X_test, y_test))
# Out:
# Train score is: 0.978507428830668
# Test score is: 0.978036517597248

# %%
#using decision tree , we calculated the training time for the model
from sklearn.linear_model import LogisticRegression

clfl = LogisticRegression(max_iter = 1200000)
start = time.time()

clfl.fit(X_train, y_train)
end = time.time()
print("Training time of Logistic Regression: ", end-start)
# Out:
# Training time of Logistic Regression:  0.1451258659362793

# %%
#evaluating model performance
print("Train score is:", clfl.score(X_train, y_train))
print("Test score is:", clfl.score(X_test, y_test))
# Out:
# Train score is: 0.9468640127027333
# Test score is: 0.948266737232072

# %%
#analysing training performance of various ml algorithms
names = ['RF','NB', 'DT', 'LR',]
values = [100, 87.7, 97.8, 94.6,]
f = plt.figure(figsize =(15, 3), num = 10)
plt.subplot(131)
plt.bar(names, values)
# Out:
# <BarContainer object of 4 artists>

# %%
#analysing testing performance of various ml algorithms
names = ['RF','NB', 'DT', 'LR',]
values = [99.7, 89.2, 97.7, 94.8,]
f = plt.figure(figsize =(15, 3), num = 10)
plt.subplot(131)
plt.bar(names, values)
# Out:
# <BarContainer object of 4 artists>

# %%
#hence , random forest classifier is best ml algorithm for our model.
